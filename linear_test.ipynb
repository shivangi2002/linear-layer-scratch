# %%
from linear import Linear

# %%
layer = Linear(input_size=3)
print("Weights:", layer.weights)
print("Bias:", layer.bias)
# Out:
# Weights: [0.582293332094835, 0.7366025744595821, 0.2730542188259193]
# Bias: 0

# %%
layer2 = Linear(input_size=3)
print("Weights:", layer2.weights)
print("Bias:", layer2.bias)
# Out:
# Weights: [0.3700255476020504, 0.9198369999462694, 0.6645289618915082]
# Bias: 0
